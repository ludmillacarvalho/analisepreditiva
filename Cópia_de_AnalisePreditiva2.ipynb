# %%
import pandas as pd
import numpy as np

# %%
viagem_2019 = pd.read_csv('/content/viagem_2019.csv', sep =";")

# %%
viagem_2020 = pd.read_csv('/content/viagem_2020.csv', sep =";")

# %%
viagem_2021 = pd.read_csv('/content/viagem_2021.csv', sep=";")

# %%
viagem_2022 = pd.read_csv('/content/viagem_2022.csv', sep=";")

# %%
viagens_servico = [viagem_2019, viagem_2020, viagem_2021, viagem_2022]

# %%
viagens_servico = pd.concat(viagens_servico)

# %%
viagens_servico
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  15045825             Sem informaçã
# 1                                  15100682             Sem informaçã
# 2                                  15114708             Sem informaçã
# 3                                  15163874             Sem informaçã
# 4                                  15166192             Sem informaçã
# ...                                     ...                       ...
# 656228                           2022000963             Sem informaçã
# 656229                           2022000974             Sem informaçã
# 656230                           2022000982             Sem informaçã
# 656231                           2022000985             Sem informaçã
# 656232                           2022001063             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %%
viagens_servico.isnull()
# Out:
#         Identificador do processo de viagem  Número da Proposta (PCDP)  \
# 0                                     False                      False
# 1                                     False                      False
# 2                                     False                      False
# 3                                     False                      False
# 4                                     False                      False
# ...                                     ...                        ...
# 656228                                False                      False
# 656229                                False                      False
# 656230                                False                      False
# 656231                                False                      False
# 656232                                False                      False
#
#         Situação  Viagem Urgente  Justificativa Urgência Viagem  \
# ...

# %%
viagens_servico.isnull().sum()
# Out:
# Identificador do processo de viagem         0
# Número da Proposta (PCDP)                   0
# Situação                                    0
# Viagem Urgente                              0
# Justificativa Urgência Viagem             119
# Código do órgão superior                    0
# Nome do órgão superior                      0
# Código órgão solicitante                    0
# Nome órgão solicitante                      0
# CPF viajante                             4023
# Nome                                        0
# Cargo                                  868283
# Função                                      0
# Descrição Função                          225
# Período - Data de início                    0
# Período - Data de fim                       0
# Destinos                                    0
# Motivo                                      2
# Valor diárias                               0
# Valor passagens                             0
# ...

# %%
viagens_servico = viagens_servico.drop_duplicates()

# %%
viagens_servico.head()
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)   Situação  \
# 0                             15045825             Sem informaçã  Realizada
# 1                             15100682             Sem informaçã  Realizada
# 2                             15114708             Sem informaçã  Realizada
# 3                             15163874             Sem informaçã  Realizada
# 4                             15166192             Sem informaçã  Realizada
#
#   Viagem Urgente Justificativa Urgência Viagem  Código do órgão superior  \
# 0            NÃO                Sem informação                     26000
# 1            NÃO                Sem informação                     26000
# 2            NÃO                Sem informação                     26000
# 3            NÃO                Sem informação                     26000
# 4            NÃO                Sem informação                     26000
#
#    Nome do órgão superior  Código órgão solicitante  \
# ...

# %%
viagens_servico.tail()
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 656228                           2022000963             Sem informaçã
# 656229                           2022000974             Sem informaçã
# 656230                           2022000982             Sem informaçã
# 656231                           2022000985             Sem informaçã
# 656232                           2022001063             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# 656228  Realizada            NÃO                Sem informação
# 656229  Realizada            NÃO                Sem informação
# 656230  Realizada            NÃO                Sem informação
# 656231  Realizada            NÃO                Sem informação
# 656232  Realizada            NÃO                Sem informação
#
#         Código do órgão superior Nome do órgão superior  \
# 656228                        -1         Sem informação
# ...

# %%
viagens_servico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2266556 entries, 0 to 656232
# Data columns (total 22 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   Identificador do processo de viagem  int64
#  1   Número da Proposta (PCDP)            object
#  2   Situação                             object
#  3   Viagem Urgente                       object
#  4   Justificativa Urgência Viagem        object
#  5   Código do órgão superior             int64
#  6   Nome do órgão superior               object
#  7   Código órgão solicitante             int64
#  8   Nome órgão solicitante               object
#  9   CPF viajante                         object
#  10  Nome                                 object
#  11  Cargo                                object
#  12  Função                               object
#  13  Descrição Função                     object
#  14  Período - Data de início             object
# ...
